# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/vimalkumar/Downloads/AmesHousing.csv')
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
pd.set_option('display.max_columns',100)

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
df.iloc[:,:15].isna().sum()
# Out:
# Order              0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage     490
# Lot Area           0
# Street             0
# Alley           2732
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# dtype: int64

# %%
df['Lot Frontage'].fillna(df['Lot Frontage'].mean(),inplace=True)

# %%
df.drop('Alley',axis=1,inplace=True)

# %%
df.iloc[:,:15].isna().sum()
# Out:
# Order           0
# PID             0
# MS SubClass     0
# MS Zoning       0
# Lot Frontage    0
# Lot Area        0
# Street          0
# Lot Shape       0
# Land Contour    0
# Utilities       0
# Lot Config      0
# Land Slope      0
# Neighborhood    0
# Condition 1     0
# Condition 2     0
# dtype: int64

# %%
df.iloc[:,15:35].isna().sum()
# Out:
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type      23
# Mas Vnr Area      23
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual         80
# Bsmt Cond         80
# Bsmt Exposure     83
# BsmtFin Type 1    80
# BsmtFin SF 1       1
# dtype: int64

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
df['Mas Vnr Area'].fillna(df['Mas Vnr Area'].mean(),inplace=True)

# %%
df['BsmtFin SF 1'].fillna(df['BsmtFin SF 1'].mean(),inplace=True)

# %%
df.iloc[:,35:55].isna().sum()
# Out:
# BsmtFin Type 2     81
# BsmtFin SF 2        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Heating             0
# Heating QC          0
# Central Air         0
# Electrical          1
# 1st Flr SF          0
# 2nd Flr SF          0
# Low Qual Fin SF     0
# Gr Liv Area         0
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Full Bath           0
# Half Bath           0
# Bedroom AbvGr       0
# Kitchen AbvGr       0
# Kitchen Qual        0
# TotRms AbvGrd       0
# dtype: int64

# %%
df['BsmtFin SF 2'].fillna(df['BsmtFin SF 2'].mean(),inplace=True)
df['Bsmt Unf SF'].fillna(df['Bsmt Unf SF'].mean(),inplace=True)
df['Total Bsmt SF'].fillna(df['Total Bsmt SF'].mean(),inplace=True)
df['Bsmt Full Bath'].fillna(df['Bsmt Full Bath'].mean(),inplace=True)
df['Bsmt Half Bath'].fillna(df['Bsmt Half Bath'].mean(),inplace=True)

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
df.iloc[:,55:82].isna().sum()
# Out:
# Functional           0
# Fireplaces           0
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Paved Drive          0
# Wood Deck SF         0
# Open Porch SF        0
# Enclosed Porch       0
# 3Ssn Porch           0
# Screen Porch         0
# Pool Area            0
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# Misc Val             0
# Mo Sold              0
# Yr Sold              0
# Sale Type            0
# Sale Condition       0
# SalePrice            0
# dtype: int64

# %%
df['Garage Yr Blt'].fillna(df['Garage Yr Blt'].mean(),inplace=True)
df['Garage Area'].fillna(df['Garage Area'].mean(),inplace=True)

# %%
df.drop('Fireplace Qu',axis=1,inplace=True)
df.drop('Pool QC',axis=1,inplace=True)
df.drop('Fence',axis=1,inplace=True)
df.drop('Misc Feature',axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2678, 77)

# %%
df.iloc[:,40:80].isna().sum()
# Out:
# Heating QC         0
# Central Air        0
# Electrical         0
# 1st Flr SF         0
# 2nd Flr SF         0
# Low Qual Fin SF    0
# Gr Liv Area        0
# Bsmt Full Bath     0
# Bsmt Half Bath     0
# Full Bath          0
# Half Bath          0
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# Kitchen Qual       0
# TotRms AbvGrd      0
# Functional         0
# Fireplaces         0
# Garage Type        0
# Garage Yr Blt      0
# Garage Finish      0
# Garage Cars        0
# Garage Area        0
# Garage Qual        0
# Garage Cond        0
# Paved Drive        0
# Wood Deck SF       0
# Open Porch SF      0
# Enclosed Porch     0
# 3Ssn Porch         0
# Screen Porch       0
# Pool Area          0
# Misc Val           0
# Mo Sold            0
# Yr Sold            0
# Sale Type          0
# Sale Condition     0
# SalePrice          0
# dtype: int64

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Garage Type',
# ...

# %%
df['Bsmt Cond'].unique()
# Out:
# array(['Gd', 'TA', 'Po', 'Fa', 'Ex'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
df['MS Zoning'] = lb.fit_transform(df['MS Zoning'])
df['Street'] = lb.fit_transform(df['Street'])
df['Lot Shape'] = lb.fit_transform(df['Lot Shape'])
df['Land Contour'] = lb.fit_transform(df['Land Contour'])
df['Utilities'] = lb.fit_transform(df['Utilities'])
df['Lot Config'] = lb.fit_transform(df['Lot Config'])
df['Land Slope'] = lb.fit_transform(df['Land Slope'])
df['Neighborhood'] = lb.fit_transform(df['Neighborhood'])
df['Condition 1'] = lb.fit_transform(df['Condition 1'])
df['Condition 2'] = lb.fit_transform(df['Condition 2'])
df['Bldg Type'] = lb.fit_transform(df['Bldg Type'])
df['House Style'] = lb.fit_transform(df['House Style'])
df['Roof Style'] = lb.fit_transform(df['Roof Style'])
df['Roof Matl'] = lb.fit_transform(df['Roof Matl'])
df['Exterior 1st'] = lb.fit_transform(df['Exterior 1st'])
df['Exterior 2nd'] = lb.fit_transform(df['Exterior 2nd'])
df['Mas Vnr Type'] = lb.fit_transform(df['Mas Vnr Type'])
df['Exter Qual'] = lb.fit_transform(df['Exter Qual'])
df['Exter Cond'] = lb.fit_transform(df['Exter Cond'])
df['Foundation'] = lb.fit_transform(df['Foundation'])
df['Bsmt Qual'] = lb.fit_transform(df['Bsmt Qual'])
df['Bsmt Cond'] = lb.fit_transform(df['Bsmt Cond'])
df['Bsmt Exposure'] = lb.fit_transform(df['Bsmt Exposure'])
df['BsmtFin Type 1'] = lb.fit_transform(df['BsmtFin Type 1'])
df['BsmtFin Type 2'] = lb.fit_transform(df['BsmtFin Type 2'])
df['Heating'] = lb.fit_transform(df['Heating'])
df['Heating QC'] = lb.fit_transform(df['Heating QC'])
df['Central Air'] = lb.fit_transform(df['Central Air'])
df['Electrical'] = lb.fit_transform(df['Electrical'])
df['Kitchen Qual'] = lb.fit_transform(df['Kitchen Qual'])
df['Functional'] = lb.fit_transform(df['Functional'])
df['Garage Type'] = lb.fit_transform(df['Garage Type'])
df['Garage Finish'] = lb.fit_transform(df['Garage Finish'])
df['Garage Qual'] = lb.fit_transform(df['Garage Qual'])
df['Garage Cond'] = lb.fit_transform(df['Garage Cond'])
df['Paved Drive'] = lb.fit_transform(df['Paved Drive'])
df['Sale Type'] = lb.fit_transform(df['Sale Type'])
df['Sale Condition'] = lb.fit_transform(df['Sale Condition'])

# %%
df.head(10)
# Out:
#    Order        PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  \
# 0      1  526301100           20          4         141.0     31770       1
# 1      2  526350040           20          3          80.0     11622       1
# 2      3  526351010           20          4          81.0     14267       1
# 3      4  526353030           20          4          93.0     11160       1
# 4      5  527105010           60          4          74.0     13830       1
# 5      6  527105030           60          4          78.0      9978       1
# 6      7  527127150          120          4          41.0      4920       1
# 7      8  527145080          120          4          43.0      5005       1
# 8      9  527146030          120          4          39.0      5389       1
# 9     10  527162130           60          4          60.0      7500       1
#
#    Lot Shape  Land Contour  Utilities  Lot Config  Land Slope  Neighborhood  \
# ...

# %%
df.shape
# Out:
# (2678, 77)

# %%
x_ind = df.iloc[:,:-1]
x_ind
# Out:
#       Order        PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# 0         1  526301100           20          4     141.00000     31770
# 1         2  526350040           20          3      80.00000     11622
# 2         3  526351010           20          4      81.00000     14267
# 3         4  526353030           20          4      93.00000     11160
# 4         5  527105010           60          4      74.00000     13830
# ...     ...        ...          ...        ...           ...       ...
# 2924   2925  923251180           20          4     160.00000     20000
# 2925   2926  923275080           80          4      37.00000      7937
# 2926   2927  923276100           20          4      69.22459      8885
# 2928   2929  924100070           20          4      77.00000     10010
# 2929   2930  924151050           60          4      74.00000      9627
#
#       Street  Lot Shape  Land Contour  Utilities  Lot Config  Land Slope  \
# ...

# %%
y_dep = df.iloc[:,-1]
y_dep
# Out:
# 0       215000
# 1       105000
# 2       172000
# 3       244000
# 4       189900
#          ...
# 2924    131000
# 2925    142500
# 2926    131000
# 2928    170000
# 2929    188000
# Name: SalePrice, Length: 2678, dtype: int64

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
scale_df = scale.fit_transform(df)

# %%
from sklearn.decomposition import PCA
pca = PCA(0.90)

# %%
x_pca = pca.fit_transform(scale_df)
x_pca
# Out:
# array([[ 0.60707565, -0.95215445,  4.31132387, ..., -0.5836683 ,
#         -0.34969612,  0.6893068 ],
#        [-3.14764827, -1.83941714,  0.1859306 , ..., -0.3185825 ,
#         -0.128833  , -0.6125927 ],
#        [-0.79815543, -1.36109189,  3.05882771, ..., -0.11065564,
#          0.97566514, -0.21993468],
#        ...,
#        [-2.05547276, -3.81146375,  1.52415045, ..., -0.21502858,
#         -0.43510221, -0.48904055],
#        [-0.61912122, -3.42244105,  2.52659177, ...,  0.32419559,
#         -0.47011269, -0.34671558],
#        [ 2.55372161,  0.99830634, -0.18168287, ..., -0.35469611,
#          0.00743245,  0.3216595 ]])

# %%
x_pca.shape
# Out:
# (2678, 48)

# %%
df.shape
# Out:
# (2678, 77)

# %%
y_dep.shape
# Out:
# (2678,)

# %% [markdown]
# # TrainTestSplit

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_pca,y_dep,random_state=5,test_size=0.2)

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (2142, 48) (2142,) (536, 48) (536,)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()

# %%
model_dt = dt.fit(x_train,y_train)

# %%
dt_pred = model_dt.predict(x_test)

# %%
dt_score = model_dt.score(x_test,y_test)*100
dt_score
# Out:
# 83.20742169014225

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rt = RandomForestRegressor()

# %%
model_rt = rt.fit(x_test,y_test)

# %%
rt_score = model_rt.score(x_test,y_test)*100
rt_score
# Out:
# 98.45158071184781

# %% [markdown]
# # Accuracy

# %%
acc = pd.DataFrame({'Model':['Decision Tree','Random Forest'],'Accuracy':[dt_score,rt_score]})
acc
# Out:
#            Model   Accuracy
# 0  Decision Tree  83.207422
# 1  Random Forest  98.451581

# %% [markdown]
# # k-means clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans()

# %%
a=[]
for i in range(1,40):
    kmeans = KMeans(i)
    kmeans.fit(x_pca)
    a.append(kmeans.inertia_)

# %%
plt.plot(range(1,40),a)

# %% [markdown]
# ### Cluster = 27

# %%
kmeans = KMeans(27)
kmeans.fit(x_pca)
k_pred = kmeans.predict(x_pca)
k_pred
# Out:
# array([ 1, 24, 23, ...,  9,  4, 10], dtype=int32)
